# %%
#cut of polynomial at given total degree
def cut(f,n):
    g = 0
    for i in range(n+1):
        for j in range(i+1):
            g = g + f.coefficient({y:j,x:(i-j)})*y^j*x^(i-j)
    return g

#implement algo from Schneiders book computes the grouplaw up to total degree deg for a given prime p and frobenius polynomial f
def grouplaw(f,deg,p):
    Polys = [0,x+y]
    for i in range(1,deg):
        H = Polys[i]
        F = f(Polys[i])-Polys[i](f(x),f(y))
        tG = cut(F,i+1)
        G = H + (-1/(p-p^(i+1)))*tG
        Polys.append(G)
    return(Polys[deg])

# %%
# %%time
R.<t> = QQ[]
f =  t^3-3*t
K.<a> = f.splitting_field()
S.<x,y> =K[]

GL=grouplaw(f,40,3)

# %%
nor = 1
for rt in f.roots(K):
     nor = nor *GL(rt[0],x)
nor
# Out:
# -...*x^77 - ...*x^75 - ...*x^73 - ...*x^71 - ...*x^69 - ...*x^67 - ...*x^65 - ...*x^63 - ...*x^61 - ...*x^59 - ...*x^57 - ...*x^55 - ...*x^53 - ...*x^51 - ...*x^49 - ...*x^47 - ...*x^45 - ...*x^43 - ...*x^41 + ...*x^39 + ...*x^37 + ...*x^35 + ...*x^33 + ...*x^31 + ...*x^29 + ...*x^27 + ...*x^25 + ...*x^23 + ...*x^21 + ...*x^19 + ...*x^17 + ...*x^15 + ...*x^13 + ...*x^11 + ...*x^9 + ...*x^7 + ...*x^5 + ...*x^3 - 3*x

# %%
v = QQ.valuation(3)
c = nor.monomial_coefficient(x^f.degree())
v(c-1)
# Out:
# 3

# %%
for i in range(4,80):
    print(i,v(nor.monomial_coefficient(x^i)))
